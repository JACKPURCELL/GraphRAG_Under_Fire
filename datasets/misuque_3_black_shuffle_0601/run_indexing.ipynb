# %%
# !original_dir=$(pwd) && cd /home/ljc/data/graphrag/ && python -m graphrag.index --root "$original_dir"
# Out:
# Logging enabled at r
# /data/jiacheng/graphrag/sp/output_question_sets/output/20250531-221830/reports/i
# ndexing-engine.log
# ⠸ GraphRAG Indexer
# ⠸ GraphRAG Indexer e.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (0 filtered) ━ 100% … 0…
# ⠧ GraphRAG Indexer
# ...
